# %%
from PIL import Image , ImageDraw , ImageFont

# %%
Image.open("Image/0.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x366 at 0x264A5A75DC8>

# %%
img=Image.open("Image/0.jpg")
draw=ImageDraw.Draw(img)
font=ImageFont.truetype("arial.ttf",80)
draw.text((80,150),"wear mask","blue",font)

# %%
img.save("Image/Img_text.jpg")

# %%
Image.open("Image/Img_text.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x366 at 0x264A5B49BC8>
