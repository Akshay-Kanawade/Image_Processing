# %%
from PIL import Image , ImageFilter

# %%
Image.open("Image/0.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x366 at 0x2BFDA5982C8>

# %%
img=Image.open("Image/0.png")

# %%
img=img.filter(ImageFilter.CONTOUR)

# %%
img.save("Image/F0.png")

# %%
Image.open("Image/F0.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x366 at 0x2BFFBA58C88>
