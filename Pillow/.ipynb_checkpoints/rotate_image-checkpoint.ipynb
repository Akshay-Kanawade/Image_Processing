# %%
from PIL import Image

# %%
Image.open("Image/0.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x366 at 0x1A4247AE248>

# %%
image=Image.open("Image/0.jpg")
image.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=512x366 at 0x1A42472F788>
