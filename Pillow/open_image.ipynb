# %%
from PIL import Image

# %% [markdown]
# # open image

# %%
Image.open('Image/0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x366 at 0x1C5D569D208>

# %%
image=Image.open("Image/1.png")
image.show()                      #show aactual image

# %% [markdown]
# # Attribute of Image

# %%
image.filename
# Out:
# 'Image/1.png'

# %%
image.mode
# Out:
# 'RGBA'

# %%
image.size
# Out:
# (512, 366)

# %%
image.width
# Out:
# 512

# %%
image.height
# Out:
# 366
