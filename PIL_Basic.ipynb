# %% [raw]
# Image processing library-        PIL(python  imaging library)
#                                                  opencv
#                                                   scikit-image
#                                                   pillow
# pillow build on pil library
# support jpeg,jpg,bmp,png,gif,ppm,tiff
#
# in pillow image class is use for performing operation on image

# %%
from PIL import Image,ImageFilter,ImageDraw,ImageFont

# %% [raw]
# we use pil library instead of pillow for the backword compability

# %%
Image.open('0.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x366 at 0x194F95594C8>

# %%
image=Image.open("0.png")
image.show()                      #show aactual image

# %%
im=image.rotate(90)
im.show()                 # show rotated image

# %%
image.rotate(90)

# %% [markdown]
# Attribute of image

# %%
image=Image.open("0.png")
image.filename

# %%
image.format

# %%
image.mode                #get pixel format used byimage

# %%
image.size

# %%
image.width

# %%
image.height

# %%
image.info

# %%
image.palette                #return color palette table

# %% [markdown]
# read an image

# %%
image=Image.open("0.png",mode='r')
image.show()
image.save("0.jpg")

# %%
Image.open("0.jpg")

# %% [markdown]
# crop image

# %%
image=Image.open("0.png")
image.crop((250,50,500,300))

# %%
Image.new("RGB",(300,300),"blue").show()

# %% [markdown]
# image filter

# %%
img=Image.open("0.png").filter(ImageFilter.CONTOUR).show()

# %% [markdown]
# write text on image

# %%
img=Image.open("1.png")
draw=ImageDraw.Draw(img)
font=ImageFont.truetype("arial.ttf",100)
draw.text((100,100),"get mask","blue",font)
img.show()

# %%
from PIL import Image

# %%
img=Image.open('0.jpg')
img.size
# Out:
# (512, 366)

# %%
Img=Image.open('0.jpg')
Img.resize((128,128))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x26219FAC648>

# %%
import numpy as np

# %%
img=np.array(img)
img
# Out:
# array([[[116, 111, 108],
#         [109, 103, 103],
#         [102,  96,  96],
#         ...,
#         [ 42,  61, 103],
#         [ 64,  85, 142],
#         [ 96, 117, 184]],
#
#        [[106, 101,  98],
#         [101,  96,  93],
#         [ 95,  89,  89],
#         ...,
#         [ 36,  55,  97],
#         [ 54,  75, 132],
#         [ 83, 104, 169]],
#
#        [[ 96,  91,  88],
#         [ 92,  87,  84],
#         [ 88,  83,  80],
#         ...,
#         [ 31,  50,  92],
#         [ 46,  67, 122],
#         [ 71,  92, 155]],
#
#        ...,
#
#        [[ 84,  82,  83],
#         [ 86,  84,  85],
#         [ 89,  87,  88],
#         ...,
#         [ 27,  26,  31],
#         [ 28,  27,  32],
#         [ 28,  27,  32]],
#
#        [[ 88,  88,  88],
#         [ 91,  91,  91],
#         [ 94,  94,  94],
#         ...,
#         [ 28,  27,  32],
#         [ 28,  27,  32],
#         [ 29,  28,  33]],
#
#        [[ 92,  92,  92],
#         [ 95,  95,  95],
#         [ 98,  98,  98],
# ...

# %%
data=[]
data.append(img)

# %%
test=np.array(data)
test
# Out:
# array([[[116, 111, 108],
#         [109, 103, 103],
#         [102,  96,  96],
#         ...,
#         [ 42,  61, 103],
#         [ 64,  85, 142],
#         [ 96, 117, 184]],
#
#        [[106, 101,  98],
#         [101,  96,  93],
#         [ 95,  89,  89],
#         ...,
#         [ 36,  55,  97],
#         [ 54,  75, 132],
#         [ 83, 104, 169]],
#
#        [[ 96,  91,  88],
#         [ 92,  87,  84],
#         [ 88,  83,  80],
#         ...,
#         [ 31,  50,  92],
#         [ 46,  67, 122],
#         [ 71,  92, 155]],
#
#        ...,
#
#        [[ 84,  82,  83],
#         [ 86,  84,  85],
#         [ 89,  87,  88],
#         ...,
#         [ 27,  26,  31],
#         [ 28,  27,  32],
#         [ 28,  27,  32]],
#
#        [[ 88,  88,  88],
#         [ 91,  91,  91],
#         [ 94,  94,  94],
#         ...,
#         [ 28,  27,  32],
#         [ 28,  27,  32],
#         [ 29,  28,  33]],
#
#        [[ 92,  92,  92],
#         [ 95,  95,  95],
#         [ 98,  98,  98],
# ...
